# %% [markdown]
# # Hands on Python Data Science - Data Science Bootcamp - Project_1 & 2

# %%
# Creating a list with different data types

my_data = [ "Alex", 26, 34.6 , True, [15, 4, 1994], { "city": "Frankfurt"}]

# %%
print(my_data)
# Out:
# ['Alex', 26, 34.6, True, [15, 4, 1994], {'city': 'Frankfurt'}]

# %%
def hello_guys():
    print("Hello! How you guys are you doing? ")
    print("I am doing well")

# %%
hello_guys()
# Out:
# Hello! How you guys are you doing?
# I am doing well
